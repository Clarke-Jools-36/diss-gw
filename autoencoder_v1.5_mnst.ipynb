# %% [markdown]
# <a href="https://colab.research.google.com/github/Clarke-Jools-36/diss-gw/blob/testing/autoencoder_v1.5_mnst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I am going to attempt to set up a simple autoencoder. First I need to create data on which to test and train the autoencoder. I will create gravitational wave sections 1 second long with 1024 samples.
# I will also create artefacts which are not gravitational waves.

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
t = np.linspace(0,1,1024) #create an array of time between 0 and 1 second with 1024 samples
a = np.zeros_like(t) #create an array of zeros to populate with amplitude values

# %%
print(len(a))
print(len(a)==len(t)) #idiot check early :)
# Out:
# 1024
# True

# %% [markdown]
# Lets start with an artifact, a sin wave which has amplidue of a bell curve

# %%
## SIN WAVE ##
A = 0 #amplitude
B = 0.01 #period
C = 0 #phase shift (horizontal)
D = 0 #amplitude shift (vertical)
## BELL CURVE ##
b = 0.03 #width of bell curve describing amplitude
c = 0.5  #phase shift (horizontal) of bell curve

for i,t_ in enumerate(t):
  A = np.e**( -((t_-c)**2 / b) ) #setting amplidude to bell curve
  #plt.plot(t_, A, "x")

  a[i] = A * np.sin( (1/B) * (t_ - C) ) + D

plt.plot(t,a)

# %% [markdown]
# We can also make the frequency of the sin wave lower at the tail ends.

# %%
for i,t_ in enumerate(t):
  A = np.e**( -((t_-c)**2 / b) ) #setting amplidude to bell curve
  
  B = -0.035 * (np.e**( -((t_-c)**2 / b) )) + 0.05 #setting freq to bell curve
  #plt.plot(t_, B, "x")
  a[i] = A * np.sin( (1/B) * (t_ - C) ) + D

plt.plot(t,a)

# %% [markdown]
# Something funky is happening here, potentially because of the syncing with the sample rate?
#
# Lets move on to grav wave like signals. These are less symettrical

# %%
t = np.linspace(0,1,1024) #create an array of time between 0 and 1 second with 1024 samples
a = np.zeros_like(t) #create an array of zeros to populate with amplitude values

# %%
## SIN WAVE ##
A = 0 #amplitude
B = 0.01 #period
C = 0 #phase shift (horizontal)
D = 0 #amplitude shift (vertical)
## POLYNOMIAL ##
b = 2 #amplitude of amplitude polynomial
c = 0.005 #amplitude of freq polynomial
d = 5 #degree of polynomial
for i,t_ in enumerate(t):
  if 0<t_<0.8:
    A = 2*t_**5 # amplitude increases with polynomial 5
    B = 0.005/t_**5 #freq increases
  else:
    A = 0

  a[i] = A * np.sin( (1/B) * (t_ - C) ) + D

plt.plot(t,a)

# %% [markdown]
# Lets make some functions, and save this data

# %%
def blip(seed = None):
  if seed == None:
    seed = np.random.randint(0,999999)
  np.random.seed(seed)


  t = np.linspace(0,1,1024) #create an array of time between 0 and 1 second with 1024 samples
  a = np.zeros_like(t) #create an array of zeros to populate with amplitude values
  A,B,C,D,b,c = 0,0.01,((np.random.rand()-0.5)),0,0.03 + (0.05*(np.random.rand()-0.5)),0.5 + (0.5*(np.random.rand()-0.5))

  randomA = (0.5*(np.random.rand()-0.5)) #maximum amplitude

  for i,t_ in enumerate(t):
    A = randomA * np.e**( -((t_-c)**2 / b) ) #setting amplidude to bell curve
    B = abs(-0.035 * (np.e**( -((t_-c)**2 / b) )) + 0.05) #setting freq to bell curve
    a[i] = A * np.sin( (1/B) * (t_ - C) ) + D

  return {"data":{"time":t,"amplitude":a},"seed":seed}

# %%
def wave(seed = None):
  if seed == None:
    seed = np.random.randint(0,999999)
  np.random.seed(seed)


  t = np.linspace(0,1,1024) #create an array of time between 0 and 1 second with 1024 samples
  a = np.zeros_like(t) #create an array of zeros to populate with amplitude values

  A,B,C,D,b,c,d = 0,0.01,((np.random.rand()-0.5)),0,2 + ((np.random.rand()-0.5)),0.005 + (0.001*(np.random.rand()-0.5)),5

  randomA = (0.5*(np.random.rand()-0.5)) #maximum amplitude

  for i,t_ in enumerate(t):
    if 0<t_<0.75+C/2:
      A = randomA * 2*t_**5 # amplitude increases with polynomial 5
      B = 0.005/t_**5 #freq increases
    else:
      A = 0

    a[i] = A * np.sin( (1/B) * (t_ - C) ) + D

  return {"data":{"time":t,"amplitude":a},"seed":seed}

# %%
blip_ = blip()
plt.plot(blip_["data"]["time"],blip_["data"]["amplitude"], label = blip_["seed"])
blip_ = blip()
plt.plot(blip_["data"]["time"],blip_["data"]["amplitude"], label = blip_["seed"])
blip_ = blip()
plt.plot(blip_["data"]["time"],blip_["data"]["amplitude"], label = blip_["seed"])

plt.legend()

# %%
wave_ = wave()
plt.plot(wave_["data"]["time"],wave_["data"]["amplitude"], label = wave_["seed"])
wave_ = wave()
plt.plot(wave_["data"]["time"],wave_["data"]["amplitude"], label = wave_["seed"])
wave_ = wave()
plt.plot(wave_["data"]["time"],wave_["data"]["amplitude"], label = wave_["seed"])


plt.legend()

# %% [markdown]
# lets make frequency time plots

# %%
wave_ = wave()
 

# Read the data

samplingFrequency, signalData = 1024, wave_["data"]["amplitude"]
signalTime = wave_["data"]["time"]



nse = 0.01 * np.random.random(size=len(signalData))
# Plot the signal read from wav file

plt.subplot(211)

plt.title('Spectrogram')

 

plt.plot(signalTime,signalData+nse)

plt.xlabel('Sample')

plt.ylabel('Amplitude')

 

plt.subplot(212)

plt.specgram(signalData+nse,Fs=samplingFrequency, vmin=None, vmax=None,noverlap=16, NFFT=32)

plt.xlabel('Time')

plt.ylabel('Frequency')
plt.axis(ymin=0, ymax=500)
 

plt.show()


def save_figure_to_numpy(fig):
    # save it to a numpy array.
    data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
    data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
    return data

# %%
wave_ = wave()
 

# Read the data

samplingFrequency, signalData = 1024, wave_["data"]["amplitude"]
signalTime = wave_["data"]["time"]



nse = 0.01 * np.random.random(size=len(signalData))
# Plot the signal read from wav file


plt.plot(signalTime,signalData+nse)
plt.xlabel('Sample')
plt.ylabel('Amplitude')

fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)

ax.specgram(signalData+nse,Fs=samplingFrequency, vmin=None, vmax=None,noverlap=16, NFFT=32)
#ax.xlabel('Time')
#ax.ylabel('Frequency')
ax.axis(ymin=0, ymax=500)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

def save_figure_to_numpy(fig):
    fig.canvas.draw()
    # save it to a numpy array.
    data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
    data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
    return data 

data = save_figure_to_numpy(fig)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:33: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
plt.imshow(data)
plt.gray()
plt.axis('off')
# Out:
# (-0.5, 431.5, 287.5, -0.5)

# %% [markdown]
# Time to start thinking about the autoencoder

# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 16  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))  #1024 make it this! #####################################
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)  #1024 make it this!####################

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %% [markdown]
# Now we create an encoder model

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %% [markdown]
# and a decoder model

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# First, we'll configure our model to use a per-pixel binary crossentropy loss, and the Adam optimizer:

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# HOLD UP, LETS TRY USING MINST FIRST

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# We will normalize all values between 0 and 1 and we will flatten the 28x28 images into vectors of size 784.

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# now lets train for 50 epochs

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 7s 23ms/step - loss: 0.3073 - val_loss: 0.2201
# Epoch 2/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.1988 - val_loss: 0.1815
# Epoch 3/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.1728 - val_loss: 0.1626
# Epoch 4/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1580 - val_loss: 0.1512
# Epoch 5/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1491 - val_loss: 0.1446
# Epoch 6/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1441 - val_loss: 0.1413
# Epoch 7/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1412 - val_loss: 0.1387
# Epoch 8/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1389 - val_loss: 0.1365
# Epoch 9/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1370 - val_loss: 0.1349
# Epoch 10/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1354 - val_loss: 0.1334
# Epoch 11/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1340 - val_loss: 0.1321
# Epoch 12/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1328 - val_loss: 0.1309
# Epoch 13/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1319 - val_loss: 0.1300
# Epoch 14/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1311 - val_loss: 0.1294
# Epoch 15/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1306 - val_loss: 0.1289
# Epoch 16/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1302 - val_loss: 0.1286
# Epoch 17/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1298 - val_loss: 0.1282
# Epoch 18/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1296 - val_loss: 0.1280
# Epoch 19/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1294 - val_loss: 0.1278
# Epoch 20/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1293 - val_loss: 0.1277
# Epoch 21/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1291 - val_loss: 0.1276
# Epoch 22/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.1290 - val_loss: 0.1274
# Epoch 23/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1289 - val_loss: 0.1273
# Epoch 24/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1288 - val_loss: 0.1272
# Epoch 25/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1287 - val_loss: 0.1272
# Epoch 26/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.1287 - val_loss: 0.1270
# Epoch 27/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1286 - val_loss: 0.1270
# Epoch 28/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1285 - val_loss: 0.1270
# Epoch 29/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1285 - val_loss: 0.1269
# Epoch 30/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1284 - val_loss: 0.1268
# Epoch 31/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1284 - val_loss: 0.1267
# Epoch 32/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1283 - val_loss: 0.1267
# Epoch 33/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1283 - val_loss: 0.1266
# Epoch 34/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1282 - val_loss: 0.1266
# Epoch 35/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1282 - val_loss: 0.1267
# Epoch 36/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1282 - val_loss: 0.1266
# Epoch 37/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1281 - val_loss: 0.1265
# Epoch 38/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1281 - val_loss: 0.1264
# Epoch 39/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1280 - val_loss: 0.1265
# Epoch 40/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1280 - val_loss: 0.1264
# Epoch 41/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1280 - val_loss: 0.1264
# Epoch 42/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.1279 - val_loss: 0.1263
# Epoch 43/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1279 - val_loss: 0.1263
# Epoch 44/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1278 - val_loss: 0.1263
# Epoch 45/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.1278 - val_loss: 0.1262
# Epoch 46/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1278 - val_loss: 0.1263
# Epoch 47/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1278 - val_loss: 0.1262
# Epoch 48/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1277 - val_loss: 0.1261
# Epoch 49/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1277 - val_loss: 0.1261
# Epoch 50/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1277 - val_loss: 0.1261

# %% [markdown]
# lets visualise

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
